# %%
from google.colab import drive
drive.mount('/content/gdrive')
# %cd gdrive/My Drive/
# %cd GoogleColab
# !git init 
# !git remote add origin https://vccheng2001:Lovelulu.2001@github.com/vccheng2001/DeepLearning.git
# !git remote -v

# !git config --global user.email 'vccheng@andrew.cmu.edu'
# !git config --global user.name 'vccheng2001'

# !git add .
# !git commit -m 'First commit'

# !git push origin master
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# [Errno 2] No such file or directory: 'gdrive/My Drive/'
# /content/gdrive/My Drive
# [Errno 2] No such file or directory: 'GoogleColab'
# /content/gdrive/My Drive
# Reinitialized existing Git repository in /content/gdrive/My Drive/.git/
# fatal: remote origin already exists.
# origin	https://vccheng2001:Lovelulu.2001@github.com/vccheng2001/DeepLearning.git (fetch)
# origin	https://vccheng2001:Lovelulu.2001@github.com/vccheng2001/DeepLearning.git (push)
# error: open("11 10 Diodes .gdoc"): Operation not supported
# error: unable to index file 11 10 Diodes .gdoc
# fatal: adding files failed
# On branch master
#
# Initial commit
#
# Untracked files:
# 	(NEW) SI_EXCEL Session Plan 2.1 Writeable (2) (1).pdf
# 	(NEW) SI_EXCEL Session Plan 2.1 Writeable (2) - Vivian Cheng (1).pdf
# 	(NEW) SI_EXCEL Session Plan 2.1 Writeable (2) - Vivian Cheng.pdf
# ...
